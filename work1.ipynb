# %% [markdown]
# <a href="https://colab.research.google.com/github/inside-river/Prog2kakushin/blob/main/work1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 10行目にcsvファイル名（csvファイルは各自が選んだもの）を入力して、そのデータの相関係数のヒートマップを出力せよ。
#
# ※csvファイルが無い場合は、あらかじめ用意してあるデータを用いて13～24行目を実行し、相関係数のヒートマップを作成せよ。
#
# ≪csvファイルが無い場合≫
#
# 　以下に示す表は、韓国から日本に訪れた観光客の費目別1人当たりの旅行消費額の推移である。このデータの全ての列同士の相関関係を調べ、相関係数のヒートマップを作成せよ。
#
# （参考文献　JNTO、”日本の観光統計データ”、https://statistics.jnto.go.jp/　、データ更新日:2020/08/05）
#
# ![スクリーンショット 2023-12-22 011226.png](data:image/png;base64,...)

# %%
# !pip install heatmapz
from heatmap import corrplot
import numpy as np
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
from pylab import rcParams

#各自csvファイル名を↓に入力し、相関係数のヒートマップを出力せよ。
data = pd.read_csv('')

#csvファイルが無ければ、13～24行目の「＃」を外し、実行せよ。
#data=pd.DataFrame([['27565','18163','9456','3739','20458','1494'],
#              ['27024','16884','9324','3029','19019','345'],
#              ['23698','16734','8768','3218','19131','156'],
#              ['26044','19260','9673','2519','22678','353'],
#              ['24820','19147','9112','2371','20137','265'],
#              ['22495','18203','8421','3306','22195','549'],
#              ['22090','17847','7505','3042','19562','234'],
#              ['22378','18435','7492','3665','19530','294'],
#              ['24974','19961','7636','3917','21549','47'],
#              ['25412','21132','7823','3742','17939','89']])
#data.index=['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']
#data.columns=['hotel_fee','food_bill','transportation_expenses','entertainment_service_fee','shopping_fee','others']

corr = data.corr(numeric_only = False)


rcParams['figure.figsize'] = 7, 7
sns.set(color_codes=True, font_scale=1.2)

plt.figure(figsize=(8, 8))
corrplot(corr, size_scale=1000)

plt.savefig('advanced_heatmap.png')
plt.show()
